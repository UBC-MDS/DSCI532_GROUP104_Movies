# %%
library(tidyverse)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.3.0 --
#
# v ggplot2 3.2.1     v purrr   0.3.3
# v tibble  2.1.3     v dplyr   0.8.3
# v tidyr   1.0.0     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
#
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
movies_df <- read_csv('../data/clean/movies_clean_df.csv', col_types = cols(X1 = col_skip()))
# Out:
# Warning message:
# "Missing column names filled in: 'X1' [1]"

# %%
movies_df %>% 
    str()
# Out:
# Classes 'spec_tbl_df', 'tbl_df', 'tbl' and 'data.frame':	1414 obs. of  7 variables:
#  $ Title         : chr  "Twelve Monkeys" "24 7: Twenty Four Seven" "Twin Falls Idaho" "Four Rooms" ...
#  $ Major_Genre   : chr  "Drama" "Comedy" "Drama" "Comedy" ...
#  $ Director      : chr  "Terry Gilliam" "Shane Meadows" "Michael Polish" "Robert Rodriguez" ...
#  $ Year          : num  1995 1998 1999 1995 1994 ...
#  $ Profit_Million: num  139.841 -1.927 0.527 0.301 238.396 ...
#  $ IMDB_Rating   : num  8.1 6.9 7.1 6.4 7.1 7.6 6.6 5.6 5.9 3.2 ...
#  $ MPAA_Rating   : chr  "R" "R" "R" "R" ...
#  - attr(*, "spec")=
#   .. cols(
#   ..   X1 = col_skip(),
#   ..   Title = col_character(),
#   ..   Major_Genre = col_character(),
#   ..   Director = col_character(),
#   ..   Year = col_double(),
#   ..   Profit_Million = col_double(),
#   ..   IMDB_Rating = col_double(),
#   ..   MPAA_Rating = col_character()
#   .. )

# %%
#' 
#' Finds the number of movies of the most productive directors in the selected genre.
#' 
#' @param df data frame the data frame to work on
#' @param num int the number of directors to keep in each genre
#' @param genre string the selected genre
#' 
#' @return a data frame only contains movie information from the most productive 
#' directors in the selected genre  
#'
get_top_director <- function(df, num, genre){

    df %>% 
        filter(Major_Genre == genre) %>%
        group_by(Director) %>%
        summarise(Count = n()) %>%
        arrange(desc(Count)) %>%
        mutate(Major_Genre = genre) %>%
        head(30)

}
top_director <- get_top_director(movies_df, 30, 'Action')

top_df <- movies_df %>% 
    inner_join(top_director, by = c("Major_Genre", "Director"))

# %%
top_director
# Out:
#    Director           Count Major_Genre
# 1  Michael Bay        7     Action
# 2  Brett Ratner       6     Action
# 3  Tony Scott         6     Action
# 4  James Cameron      5     Action
# 5  Andy Wachowski     4     Action
# 6  John Woo           4     Action
# 7  Renny Harlin       4     Action
# 8  Richard Donner     4     Action
# 9  Rob Cohen          4     Action
# 10 Steven Spielberg   4     Action
# 11 Antoine Fuqua      3     Action
# 12 Guillermo Del Toro 3     Action
# 13 Jan De Bont        3     Action
# 14 Joel Schumacher    3     Action
# 15 John McTiernan     3     Action
# 16 Jonathan Mostow    3     Action
# 17 Len Wiseman        3     Action
# 18 Martin Campbell    3     Action
# 19 Peter Berg         3     Action
# 20 Peter Hyams        3     Action
# 21 Quentin Tarantino  3     Action
# 22 Ridley Scott       3     Action
# 23 Robert Rodriguez   3     Action
# 24 Roland Emmerich    3     Action
# 25 Russell Mulcahy    3     Action
# 26 Stephen Sommers    3     Action
# 27 Andrew Davis       2     Action
# 28 Andrzej Bartkowiak 2     Action
# 29 Bryan Singer       2     Action
# 30 Christopher Nolan  2     Action

# %%
top_df
# Out:
#     Title                               Major_Genre Director           Year
# 1   The Abyss                           Action      James Cameron      1989
# 2   Bad Boys                            Action      Michael Bay        1995
# 3   Beverly Hills Cop II                Action      Tony Scott         1987
# 4   Broken Arrow                        Action      John Woo           1996
# 5   Batman Forever                      Action      Joel Schumacher    1995
# 6   Chain Reaction                      Action      Andrew Davis       1996
# 7   Crimson Tide                        Action      Tony Scott         1995
# 8   Desperado                           Action      Robert Rodriguez   1995
# 9   Daylight                            Action      Rob Cohen          1996
# 10  Die Hard: With a Vengeance          Action      John McTiernan     1995
# 11  Goldeneye                           Action      Martin Campbell    1995
# 12  Highlander                          Action      Russell Mulcahy    1986
# 13  Jurassic Park                       Action      Steven Spielberg   1993
# 14  The Long Kiss Goodnight             Action      Renny Harlin       1996
# 15  Aliens                              Action      James Cameron      1986
# 16  Lethal Weapon 3                     Action      Richard Donner     1992
# 17  The Rock                            Action      Michael Bay        1996
# 18  Stargate                            Action      Roland Emmerich    1994
# 19  The Shadow                          Action      Russell Mulcahy    1994
# 20  Speed                               Action      Jan De Bont        1994
# 21  Assassins                           Action      Richard Donner     1995
# 22  Timecop                             Action      Peter Hyams        1994
# 23  True Lies                           Action      James Cameron      1994
# 24  Terminator 2: Judgment Day          Action      James Cameron      1991
# 25  Twister                             Action      Jan De Bont        1996
# 26  12 Rounds                           Action      Renny Harlin       2009
# 27  16 Blocks                           Action      Richard Donner     2006
# 28  2012                                Action      Roland Emmerich    2009
# 29  After the Sunset                    Action      Brett Ratner       2004
# 30  Avatar                              Action      James Cameron      2009
# ... ...                                 ...         ...                ...
# 75  Resident Evil: Extinction           Action      Russell Mulcahy    2007
# 76  Romeo Must Die                      Action      Andrzej Bartkowiak 2000
# 77  The Rundown                         Action      Peter Berg         2003
# 78  Rush Hour 2                         Action      Brett Ratner       2001
# 79  Rush Hour 3                         Action      Brett Ratner       2007
# 80  Rush Hour                           Action      Brett Ratner       1998
# 81  Sin City                            Action      Robert Rodriguez   2005
# 82  A Sound of Thunder                  Action      Peter Hyams        2005
# 83  Speed Racer                         Action      Andy Wachowski     2008
# 84  Speed II: Cruise Control            Action      Jan De Bont        1997
# 85  Spy Game                            Action      Tony Scott         2001
# 86  Stealth                             Action      Rob Cohen          2005
# 87  Surrogates                          Action      Jonathan Mostow    2009
# 88  Tears of the Sun                    Action      Antoine Fuqua      2003
# 89  Terminator 3: Rise of the Machines  Action      Jonathan Mostow    2003
# 90  Transformers                        Action      Michael Bay        2007
# 91  Transformers: Revenge of the Fallen Action      Michael Bay        2009
# 92  The 13th Warrior                    Action      John McTiernan     1999
# 93  The Taking of Pelham 123            Action      Tony Scott         2009
# 94  xXx                                 Action      Rob Cohen          2002
# 95  U-571                               Action      Jonathan Mostow    2000
# 96  Underworld                          Action      Len Wiseman        2003
# 97  Underworld: Evolution               Action      Len Wiseman        2006
# 98  Van Helsing                         Action      Stephen Sommers    2004
# 99  Vertical Limit                      Action      Martin Campbell    2000
# 100 The War of the Worlds               Action      Steven Spielberg   2005
# 101 Windtalkers                         Action      John Woo           2002
# 102 X-Men                               Action      Bryan Singer       2000
# 103 X2                                  Action      Bryan Singer       2003
# 104 X-Men: The Last Stand               Action      Brett Ratner       2006
#     Profit_Million IMDB_Rating MPAA_Rating Count
# 1    -15.756875    7.6         PG-13       5
# 2    118.247413    6.6         R           7
# 3    256.665036    6.1         R           6
# 4     83.345997    5.8         R           4
# 5    236.529144    5.4         PG-13       3
# 6      5.209334    5.2         PG-13       2
# 7    104.387195    7.2         R           6
# 8     18.532388    7.0         R           3
# 9     78.908290    5.4         PG-13       4
# 10   274.480746    7.4         R           3
# 11   296.429941    7.2         PG-13       3
# 12    -3.100000    7.2         R           3
# 13   860.067947    7.9         PG-13       4
# 14   -31.552388    6.6         R           4
# 15   166.316455    7.5         R           5
# 16   284.700000    6.5         R           4
# 17   261.069511    7.2         R           7
# 18   141.565669    6.7         PG-13       3
# 19    -8.164400    5.6         PG-13       3
# 20   253.200000    2.6         R           3
# 21    33.306268    5.9         R           4
# 22    74.053581    5.5         R           3
# 23   265.300000    7.2         R           5
# 24   416.816151    8.5         R           5
# 25   407.900000    6.0         PG-13       3
# 26    -1.815917    5.4         PG-13       4
# 27    20.595141    6.7         PG-13       4
# 28   566.812167    6.2         PG-13       3
# 29   -18.670886    6.2         PG-13       6
# 30  2530.891499    8.3         PG-13       5
# ... ...            ...         ...         ...
# 75  101.162920     6.2         R           3
# 76   66.036760     5.9         R           2
# 77   -4.168107     6.6         PG-13       3
# 78  257.425832     6.4         PG-13       6
# 79   73.025968     6.0         PG-13       6
# 80  210.300000     6.8         PG-13       6
# 81  118.753820     8.3         R           3
# 82  -73.699549     4.1         PG-13       3
# 83  -26.605538     6.3         PG          4
# 84   40.468000     3.4         PG-13       3
# 85   53.049560     6.9         R           6
# 86  -61.583254     4.8         PG-13       4
# 87   39.668350     6.3         PG-13       3
# 88   10.632458     6.4         R           3
# 89  263.058296     6.6         R           3
# 90  557.272592     7.3         PG-13       7
# 91  626.303693     6.0         PG-13       7
# 92  -63.301101     6.3         R           3
# 93   38.989667     6.5         R           6
# 94  197.200000     5.5         PG-13       4
# 95   65.630030     6.4         PG-13       3
# 96   73.708457     6.7         R           3
# 97   66.318875     6.6         R           3
# 98  130.150546     5.5         PG-13       3
# 99  138.500000     5.6         PG-13       3
# 100 459.745532     7.2         PG-13       4
# 101 -37.371735     5.8         R           4
# 102 259.627820     7.4         PG-13       2
# 103 282.711549     7.8         PG-13       2
# 104 309.359555     6.9         PG-13       6
